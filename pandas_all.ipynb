# %% [markdown]
# <a href="https://colab.research.google.com/github/RuchikaMansi/ruchu263/blob/main/pandas_all.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
std_data=[(1,'varun',30,'male','chandigarh'),
          (2,'rishi',22,'male','haryana'),
          (3,'priti',21,'female','punjab'),
          (4,'kirti',20,'femlae','delhi'),
          (5,'krish',None,'male',''),
          (6 ,'mehul',22 ,'male','punjab')]
df=pd.DataFrame(std_data,columns=['stud_id','Name','Age','Gender','City'])
print(df)
# Out:
#    stud_id   Name   Age  Gender        City
# 0        1  varun  30.0    male  chandigarh
# 1        2  rishi  22.0    male     haryana
# 2        3  priti  21.0  female      punjab
# 3        4  kirti  20.0  femlae       delhi
# 4        5  krish   NaN    male
# 5        6  mehul  22.0    male      punjab

# %%
import pandas as pd
df=pd.read_csv("std_data")
print(df)

# %%
path="/content/stud.csv.xlsx"

# %%
import pandas as pd

df = pd.read_csv(path)

df = df.dropna()
print(df)
# Out:
#        stud_id   Name  Age  Gender     Address
# 0   0        1  varun   30    male  chandigarh
# 1   1        2  rishi   22    male     haryana
# 2   2        3  priti   21  female      punjab
# 3   3        4  kirti   20  femlae       delhi
# 4           4\t 5  0        0   0            0
# 5  5        6  mehul   22   male        punjab

# %%
import pandas as pd

data = {'name': ['Alice', None, 'Charlie', 'David', 'Eva'],
        'age': [25, 30, 35, 40, None],
        'salary': [50000, 60000, None, 80000, 90000]}

df = pd.DataFrame(data)
df_filtered = df[(df['name'] != '')]

print(df_filtered)
constant_values = {'name':'hrf','age':20,'salary':2000}
df = df.fillna(value = constant_values)

# Printing the dataframe
display(df)
# Out:
#       name   age   salary
# 0    Alice  25.0  50000.0
# 1     None  30.0  60000.0
# 2  Charlie  35.0      NaN
# 3    David  40.0  80000.0
# 4      Eva   NaN  90000.0
#       name   age   salary
# 0    Alice  25.0  50000.0
# 1      hrf  30.0  60000.0
# 2  Charlie  35.0   2000.0
# 3    David  40.0  80000.0
# 4      Eva  20.0  90000.0
